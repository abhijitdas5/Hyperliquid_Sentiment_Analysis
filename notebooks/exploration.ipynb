# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

fear = pd.read_csv("../data/fear_greed_index.csv")

trade = pd.read_csv("../data/historical_data.csv")

fear.head()
trade.head()
# Out:
# Running cells with 'Python 3.11.7' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/abhi5/AppData/Local/Programs/Python/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall'
